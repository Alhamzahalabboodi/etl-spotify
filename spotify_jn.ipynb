# %%
#Dependencies
import requests
import json
import csv
import pandas as pd
import numpy as np
import sqlalchemy
from sqlalchemy.orm import sessionmaker
from datetime import datetime
import datetime
import sqlite3
import matplotlib.pyplot as plt
from pprint import pprint
from sqlalchemy import create_engine

# %%
# My Spotify info
# Make an api request to extract the data from Spotify
user_id = "Alhamzah.alabboodi"
url = "https://api.spotify.com/v1/me/player/recently-played?after="
TOKEN = "BQCX70q3crylBpXfqeItcvwyEI_5MK_LIKYlPPqJQ--mLw0Fn88yBBG-esmQTaPvrSDtFh2fQPdo5pvIx6kvVtgGhaeFpWFRE-9KG3u3tCoLZw33AMG237yNBm2i1qI37SVNd6_Tqy4XKy24zVQ8rCclRq4inikHNasGHWEs5KRSb8bcPn1iolU0Yv-eHzs"

# Step number 2 : transform (validate)
# Create a function that checks for validations (this is typically boolean)
def check_if_validate_data(df: pd.DataFrame)-> bool:
    # Check if the dataframe is empty
    if df.empty:
        print("No songs downloaded. Finishing excution")
        return False
    # Identify the primary key to preform Primary Key Check --> (played_at) because it has timestamps
    if pd.Series(df["played_at"]).is_unique:
        pass
    else:
        raise Exception("Primary Key Check is violated")
    # Check for nulls
    if df.isnull().value.any():
        raise Exception("Null valued found")
    # Check that all timestamps are of yesterday's date
    yesterday = datetime.datetime.now() - datetime.timedelta(days=1)
    yesterday = yesterday.replace(hour=0, minute=0, second=0, microsecond=0)
    
    timestamps = df["timestamp"].tolist()
    for timestamp in timestamps:
        if datetime.datetime.strftime(timestamps, "%Y-%m-%d") != yesterday:
            raise Exception("At least one of the returned songs does not come from within the last 24 hours")
    
    return True 


# Step number 1 : extract 
if __name__ == "__main__":
    
    headers = {
        "Accept" : "application/json",
        "content-Type" : "application/json",
        "Authorization" : "Bearer {token}".format(token=TOKEN)
    }
    #sicne today's unix timestamp in milliseconds, we need to convert yesterday's as well
    today = datetime.datetime.now()
    yesterday = today - datetime.timedelta(days=1)
    yesterday_unix_timestamp = int(yesterday.timestamp()) *1000
    
    #preform the request
    request =  requests.get("https://api.spotify.com/v1/me/player/recently-played?after={time}".format(time = yesterday_unix_timestamp), headers = headers)
    response = request.json()
    pprint(response)
# Out:
# {'cursors': {'after': '1666454188176', 'before': '1666392219225'},
#  'href': 'https://api.spotify.com/v1/me/player/recently-played?after=1666377336000',
#  'items': [{'context': None,
#             'played_at': '2022-10-22T15:56:28.176Z',
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/28j8lBWDdDSHSSt5oPlsX2'},
#                                              'href': 'https://api.spotify.com/v1/artists/28j8lBWDdDSHSSt5oPlsX2',
#                                              'id': '28j8lBWDdDSHSSt5oPlsX2',
#                                              'name': 'ZHU',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:28j8lBWDdDSHSSt5oPlsX2'}],
#                                 'available_markets': ['AD',
#                                                       'AE',
#                                                       'AG',
#                                                       'AL',
#                                                       'AM',
#                                                       'AO',
#                                                       'AR',
#                                                       'AT',
#                                                       'AU',
#                                                       'AZ',
#                                                       'BA',
#                                                       'BB',
#                                                       'BD',
#                                                       'BE',
#                                                       'BF',
#                                                       'BG',
#                                                       'BH',
#                                                       'BI',
#                                                       'BJ',
#                                                       'BN',
#                                                       'BO',
#                                                       'BR',
#                                                       'BS',
#                                                       'BT',
#                                                       'BW',
#                                                       'BY',
#                                                       'BZ',
#                                                       'CA',
#                                                       'CD',
#                                                       'CG',
#                                                       'CH',
#                                                       'CI',
#                                                       'CL',
#                                                       'CM',
#                                                       'CO',
#                                                       'CR',
#                                                       'CV',
#                                                       'CW',
#                                                       'CY',
#                                                       'CZ',
#                                                       'DE',
#                                                       'DJ',
#                                                       'DK',
#                                                       'DM',
#                                                       'DO',
#                                                       'DZ',
#                                                       'EC',
#                                                       'EE',
#                                                       'EG',
#                                                       'ES',
#                                                       'FI',
#                                                       'FJ',
#                                                       'FM',
#                                                       'FR',
#                                                       'GA',
#                                                       'GB',
#                                                       'GD',
#                                                       'GE',
#                                                       'GH',
#                                                       'GM',
#                                                       'GN',
#                                                       'GQ',
#                                                       'GR',
#                                                       'GT',
#                                                       'GW',
#                                                       'GY',
#                                                       'HK',
#                                                       'HN',
#                                                       'HR',
#                                                       'HT',
#                                                       'HU',
#                                                       'ID',
#                                                       'IE',
#                                                       'IL',
#                                                       'IN',
#                                                       'IQ',
#                                                       'IS',
#                                                       'IT',
#                                                       'JM',
#                                                       'JO',
#                                                       'JP',
#                                                       'KE',
#                                                       'KG',
#                                                       'KH',
#                                                       'KI',
#                                                       'KM',
#                                                       'KN',
#                                                       'KR',
#                                                       'KW',
#                                                       'KZ',
#                                                       'LA',
#                                                       'LB',
#                                                       'LC',
#                                                       'LI',
#                                                       'LK',
#                                                       'LR',
#                                                       'LS',
#                                                       'LT',
#                                                       'LU',
#                                                       'LV',
#                                                       'LY',
#                                                       'MA',
#                                                       'MC',
#                                                       'MD',
#                                                       'ME',
#                                                       'MG',
#                                                       'MH',
#                                                       'MK',
#                                                       'ML',
#                                                       'MN',
#                                                       'MO',
#                                                       'MR',
#                                                       'MT',
#                                                       'MU',
#                                                       'MV',
#                                                       'MW',
#                                                       'MX',
#                                                       'MY',
#                                                       'MZ',
#                                                       'NA',
#                                                       'NE',
#                                                       'NG',
#                                                       'NI',
#                                                       'NL',
#                                                       'NO',
#                                                       'NP',
#                                                       'NR',
#                                                       'NZ',
#                                                       'OM',
#                                                       'PA',
#                                                       'PE',
#                                                       'PG',
#                                                       'PH',
#                                                       'PK',
#                                                       'PL',
#                                                       'PS',
#                                                       'PT',
#                                                       'PW',
#                                                       'PY',
#                                                       'QA',
#                                                       'RO',
#                                                       'RS',
#                                                       'RW',
#                                                       'SA',
#                                                       'SB',
#                                                       'SC',
#                                                       'SE',
#                                                       'SG',
#                                                       'SI',
#                                                       'SK',
#                                                       'SL',
#                                                       'SM',
#                                                       'SN',
#                                                       'SR',
#                                                       'ST',
#                                                       'SV',
#                                                       'SZ',
#                                                       'TD',
#                                                       'TG',
#                                                       'TH',
#                                                       'TJ',
#                                                       'TL',
#                                                       'TN',
#                                                       'TO',
#                                                       'TR',
#                                                       'TT',
#                                                       'TV',
#                                                       'TW',
#                                                       'TZ',
#                                                       'UA',
#                                                       'UG',
#                                                       'US',
#                                                       'UY',
#                                                       'UZ',
#                                                       'VC',
#                                                       'VE',
#                                                       'VN',
#                                                       'VU',
#                                                       'WS',
#                                                       'XK',
#                                                       'ZA',
#                                                       'ZM',
#                                                       'ZW'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/7yMUYER67OvjIuGqBgrdZO'},
#                                 'href': 'https://api.spotify.com/v1/albums/7yMUYER67OvjIuGqBgrdZO',
#                                 'id': '7yMUYER67OvjIuGqBgrdZO',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273808d6f46a6d55690eca3d601',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02808d6f46a6d55690eca3d601',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851808d6f46a6d55690eca3d601',
#                                             'width': 64}],
#                                 'name': 'DREAMLAND (DELUXE)',
#                                 'release_date': '2021-12-31',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 19,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:7yMUYER67OvjIuGqBgrdZO'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/28j8lBWDdDSHSSt5oPlsX2'},
#                                    'href': 'https://api.spotify.com/v1/artists/28j8lBWDdDSHSSt5oPlsX2',
#                                    'id': '28j8lBWDdDSHSSt5oPlsX2',
#                                    'name': 'ZHU',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:28j8lBWDdDSHSSt5oPlsX2'},
#                                   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0IEPb9ily3E5IAYMSkwtQ6'},
#                                    'href': 'https://api.spotify.com/v1/artists/0IEPb9ily3E5IAYMSkwtQ6',
#                                    'id': '0IEPb9ily3E5IAYMSkwtQ6',
#                                    'name': 'Arctic Lake',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:0IEPb9ily3E5IAYMSkwtQ6'}],
#                       'available_markets': ['AD',
#                                             'AE',
#                                             'AG',
#                                             'AL',
#                                             'AM',
#                                             'AO',
#                                             'AR',
#                                             'AT',
#                                             'AU',
#                                             'AZ',
#                                             'BA',
#                                             'BB',
#                                             'BD',
#                                             'BE',
#                                             'BF',
#                                             'BG',
#                                             'BH',
#                                             'BI',
#                                             'BJ',
#                                             'BN',
#                                             'BO',
#                                             'BR',
#                                             'BS',
#                                             'BT',
#                                             'BW',
#                                             'BY',
#                                             'BZ',
#                                             'CA',
#                                             'CD',
#                                             'CG',
#                                             'CH',
#                                             'CI',
#                                             'CL',
#                                             'CM',
#                                             'CO',
#                                             'CR',
#                                             'CV',
#                                             'CW',
#                                             'CY',
#                                             'CZ',
#                                             'DE',
#                                             'DJ',
#                                             'DK',
#                                             'DM',
#                                             'DO',
#                                             'DZ',
#                                             'EC',
#                                             'EE',
#                                             'EG',
#                                             'ES',
#                                             'FI',
#                                             'FJ',
#                                             'FM',
#                                             'FR',
#                                             'GA',
#                                             'GB',
#                                             'GD',
#                                             'GE',
#                                             'GH',
#                                             'GM',
#                                             'GN',
#                                             'GQ',
#                                             'GR',
#                                             'GT',
#                                             'GW',
#                                             'GY',
#                                             'HK',
#                                             'HN',
#                                             'HR',
#                                             'HT',
#                                             'HU',
#                                             'ID',
#                                             'IE',
#                                             'IL',
#                                             'IN',
#                                             'IQ',
#                                             'IS',
#                                             'IT',
#                                             'JM',
#                                             'JO',
#                                             'JP',
#                                             'KE',
#                                             'KG',
#                                             'KH',
#                                             'KI',
#                                             'KM',
#                                             'KN',
#                                             'KR',
#                                             'KW',
#                                             'KZ',
#                                             'LA',
#                                             'LB',
#                                             'LC',
#                                             'LI',
#                                             'LK',
#                                             'LR',
#                                             'LS',
#                                             'LT',
#                                             'LU',
#                                             'LV',
#                                             'LY',
#                                             'MA',
#                                             'MC',
#                                             'MD',
#                                             'ME',
#                                             'MG',
#                                             'MH',
#                                             'MK',
#                                             'ML',
#                                             'MN',
#                                             'MO',
#                                             'MR',
#                                             'MT',
#                                             'MU',
#                                             'MV',
#                                             'MW',
#                                             'MX',
#                                             'MY',
#                                             'MZ',
#                                             'NA',
#                                             'NE',
#                                             'NG',
#                                             'NI',
#                                             'NL',
#                                             'NO',
#                                             'NP',
#                                             'NR',
#                                             'NZ',
#                                             'OM',
#                                             'PA',
#                                             'PE',
#                                             'PG',
#                                             'PH',
#                                             'PK',
#                                             'PL',
#                                             'PS',
#                                             'PT',
#                                             'PW',
#                                             'PY',
#                                             'QA',
#                                             'RO',
#                                             'RS',
#                                             'RW',
#                                             'SA',
#                                             'SB',
#                                             'SC',
#                                             'SE',
#                                             'SG',
#                                             'SI',
#                                             'SK',
#                                             'SL',
#                                             'SM',
#                                             'SN',
#                                             'SR',
#                                             'ST',
#                                             'SV',
#                                             'SZ',
#                                             'TD',
#                                             'TG',
#                                             'TH',
#                                             'TJ',
#                                             'TL',
#                                             'TN',
#                                             'TO',
#                                             'TR',
#                                             'TT',
#                                             'TV',
#                                             'TW',
#                                             'TZ',
#                                             'UA',
#                                             'UG',
#                                             'US',
#                                             'UY',
#                                             'UZ',
#                                             'VC',
#                                             'VE',
#                                             'VN',
#                                             'VU',
#                                             'WS',
#                                             'XK',
#                                             'ZA',
#                                             'ZM',
#                                             'ZW'],
#                       'disc_number': 1,
#                       'duration_ms': 257734,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USUG12100930'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/3xtrM3vQ6UsLQcI3edvtv4'},
#                       'href': 'https://api.spotify.com/v1/tracks/3xtrM3vQ6UsLQcI3edvtv4',
#                       'id': '3xtrM3vQ6UsLQcI3edvtv4',
#                       'is_local': False,
#                       'name': 'Yours',
#                       'popularity': 45,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/776a24e791593956037903897e7155d2d156e94e?cid=774b29d4f13844c495f206cafdad9c86',
#                       'track_number': 13,
#                       'type': 'track',
#                       'uri': 'spotify:track:3xtrM3vQ6UsLQcI3edvtv4'}},
#            {'context': None,
#             'played_at': '2022-10-22T15:50:45.056Z',
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Wk167T0fY1fABsHM5qFcI'},
#                                              'href': 'https://api.spotify.com/v1/artists/2Wk167T0fY1fABsHM5qFcI',
#                                              'id': '2Wk167T0fY1fABsHM5qFcI',
#                                              'name': 'Sherine',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:2Wk167T0fY1fABsHM5qFcI'}],
#                                 'available_markets': ['AD',
#                                                       'AE',
#                                                       'AG',
#                                                       'AL',
#                                                       'AM',
#                                                       'AO',
#                                                       'AR',
#                                                       'AT',
#                                                       'AU',
#                                                       'AZ',
#                                                       'BA',
#                                                       'BB',
#                                                       'BD',
#                                                       'BE',
#                                                       'BF',
#                                                       'BG',
#                                                       'BH',
#                                                       'BI',
#                                                       'BJ',
#                                                       'BN',
#                                                       'BO',
#                                                       'BR',
#                                                       'BS',
#                                                       'BT',
#                                                       'BW',
#                                                       'BY',
#                                                       'BZ',
#                                                       'CA',
#                                                       'CD',
#                                                       'CG',
#                                                       'CH',
#                                                       'CI',
#                                                       'CL',
#                                                       'CM',
#                                                       'CO',
#                                                       'CR',
#                                                       'CV',
#                                                       'CW',
#                                                       'CY',
#                                                       'CZ',
#                                                       'DE',
#                                                       'DJ',
#                                                       'DK',
#                                                       'DM',
#                                                       'DO',
#                                                       'DZ',
#                                                       'EC',
#                                                       'EE',
#                                                       'EG',
#                                                       'ES',
#                                                       'FI',
#                                                       'FJ',
#                                                       'FM',
#                                                       'FR',
#                                                       'GA',
#                                                       'GB',
#                                                       'GD',
#                                                       'GE',
#                                                       'GH',
#                                                       'GM',
#                                                       'GN',
#                                                       'GQ',
#                                                       'GR',
#                                                       'GT',
#                                                       'GW',
#                                                       'GY',
#                                                       'HK',
#                                                       'HN',
#                                                       'HR',
#                                                       'HT',
#                                                       'HU',
#                                                       'ID',
#                                                       'IE',
#                                                       'IL',
#                                                       'IN',
#                                                       'IQ',
#                                                       'IS',
#                                                       'IT',
#                                                       'JM',
#                                                       'JO',
#                                                       'JP',
#                                                       'KE',
#                                                       'KG',
#                                                       'KH',
#                                                       'KI',
#                                                       'KM',
#                                                       'KN',
#                                                       'KR',
#                                                       'KW',
#                                                       'KZ',
#                                                       'LA',
#                                                       'LB',
#                                                       'LC',
#                                                       'LI',
#                                                       'LK',
#                                                       'LR',
#                                                       'LS',
#                                                       'LT',
#                                                       'LU',
#                                                       'LV',
#                                                       'LY',
#                                                       'MA',
#                                                       'MC',
#                                                       'MD',
#                                                       'ME',
#                                                       'MG',
#                                                       'MH',
#                                                       'MK',
#                                                       'ML',
#                                                       'MN',
#                                                       'MO',
#                                                       'MR',
#                                                       'MT',
#                                                       'MU',
#                                                       'MV',
#                                                       'MW',
#                                                       'MX',
#                                                       'MY',
#                                                       'MZ',
#                                                       'NA',
#                                                       'NE',
#                                                       'NG',
#                                                       'NI',
#                                                       'NL',
#                                                       'NO',
#                                                       'NP',
#                                                       'NR',
#                                                       'NZ',
#                                                       'OM',
#                                                       'PA',
#                                                       'PE',
#                                                       'PG',
#                                                       'PH',
#                                                       'PK',
#                                                       'PL',
#                                                       'PS',
#                                                       'PT',
#                                                       'PW',
#                                                       'PY',
#                                                       'QA',
#                                                       'RO',
#                                                       'RS',
#                                                       'RW',
#                                                       'SA',
#                                                       'SB',
#                                                       'SC',
#                                                       'SE',
#                                                       'SG',
#                                                       'SI',
#                                                       'SK',
#                                                       'SL',
#                                                       'SM',
#                                                       'SN',
#                                                       'SR',
#                                                       'ST',
#                                                       'SV',
#                                                       'SZ',
#                                                       'TD',
#                                                       'TG',
#                                                       'TH',
#                                                       'TJ',
#                                                       'TL',
#                                                       'TN',
#                                                       'TO',
#                                                       'TR',
#                                                       'TT',
#                                                       'TV',
#                                                       'TW',
#                                                       'TZ',
#                                                       'UA',
#                                                       'UG',
#                                                       'US',
#                                                       'UY',
#                                                       'UZ',
#                                                       'VC',
#                                                       'VE',
#                                                       'VN',
#                                                       'VU',
#                                                       'WS',
#                                                       'XK',
#                                                       'ZA',
#                                                       'ZM',
#                                                       'ZW'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/1aCq7XjXXVc3WxPYYUrbeP'},
#                                 'href': 'https://api.spotify.com/v1/albums/1aCq7XjXXVc3WxPYYUrbeP',
#                                 'id': '1aCq7XjXXVc3WxPYYUrbeP',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273cfa4e906cda39d8f62fe81e3',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02cfa4e906cda39d8f62fe81e3',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851cfa4e906cda39d8f62fe81e3',
#                                             'width': 64}],
#                                 'name': 'نساى',
#                                 'release_date': '2018-10-24',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 12,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:1aCq7XjXXVc3WxPYYUrbeP'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Wk167T0fY1fABsHM5qFcI'},
#                                    'href': 'https://api.spotify.com/v1/artists/2Wk167T0fY1fABsHM5qFcI',
#                                    'id': '2Wk167T0fY1fABsHM5qFcI',
#                                    'name': 'Sherine',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:2Wk167T0fY1fABsHM5qFcI'}],
#                       'available_markets': ['AD',
#                                             'AE',
#                                             'AG',
#                                             'AL',
#                                             'AM',
#                                             'AO',
#                                             'AR',
#                                             'AT',
#                                             'AU',
#                                             'AZ',
#                                             'BA',
#                                             'BB',
#                                             'BD',
#                                             'BE',
#                                             'BF',
#                                             'BG',
#                                             'BH',
#                                             'BI',
#                                             'BJ',
#                                             'BN',
#                                             'BO',
#                                             'BR',
#                                             'BS',
#                                             'BT',
#                                             'BW',
#                                             'BY',
#                                             'BZ',
#                                             'CA',
#                                             'CD',
#                                             'CG',
#                                             'CH',
#                                             'CI',
#                                             'CL',
#                                             'CM',
#                                             'CO',
#                                             'CR',
#                                             'CV',
#                                             'CW',
#                                             'CY',
#                                             'CZ',
#                                             'DE',
#                                             'DJ',
#                                             'DK',
#                                             'DM',
#                                             'DO',
#                                             'DZ',
#                                             'EC',
#                                             'EE',
#                                             'EG',
#                                             'ES',
#                                             'FI',
#                                             'FJ',
#                                             'FM',
#                                             'FR',
#                                             'GA',
#                                             'GB',
#                                             'GD',
#                                             'GE',
#                                             'GH',
#                                             'GM',
#                                             'GN',
#                                             'GQ',
#                                             'GR',
#                                             'GT',
#                                             'GW',
#                                             'GY',
#                                             'HK',
#                                             'HN',
#                                             'HR',
#                                             'HT',
#                                             'HU',
#                                             'ID',
#                                             'IE',
#                                             'IL',
#                                             'IN',
#                                             'IQ',
#                                             'IS',
#                                             'IT',
#                                             'JM',
#                                             'JO',
#                                             'JP',
#                                             'KE',
#                                             'KG',
#                                             'KH',
#                                             'KI',
#                                             'KM',
#                                             'KN',
#                                             'KR',
#                                             'KW',
#                                             'KZ',
#                                             'LA',
#                                             'LB',
#                                             'LC',
#                                             'LI',
#                                             'LK',
#                                             'LR',
#                                             'LS',
#                                             'LT',
#                                             'LU',
#                                             'LV',
#                                             'LY',
#                                             'MA',
#                                             'MC',
#                                             'MD',
#                                             'ME',
#                                             'MG',
#                                             'MH',
#                                             'MK',
#                                             'ML',
#                                             'MN',
#                                             'MO',
#                                             'MR',
#                                             'MT',
#                                             'MU',
#                                             'MV',
#                                             'MW',
#                                             'MX',
#                                             'MY',
#                                             'MZ',
#                                             'NA',
#                                             'NE',
#                                             'NG',
#                                             'NI',
#                                             'NL',
#                                             'NO',
#                                             'NP',
#                                             'NR',
#                                             'NZ',
#                                             'OM',
#                                             'PA',
#                                             'PE',
#                                             'PG',
#                                             'PH',
#                                             'PK',
#                                             'PL',
#                                             'PS',
#                                             'PT',
#                                             'PW',
#                                             'PY',
#                                             'QA',
#                                             'RO',
#                                             'RS',
#                                             'RW',
#                                             'SA',
#                                             'SB',
#                                             'SC',
#                                             'SE',
#                                             'SG',
#                                             'SI',
#                                             'SK',
#                                             'SL',
#                                             'SM',
#                                             'SN',
#                                             'SR',
#                                             'ST',
#                                             'SV',
#                                             'SZ',
#                                             'TD',
#                                             'TG',
#                                             'TH',
#                                             'TJ',
#                                             'TL',
#                                             'TN',
#                                             'TO',
#                                             'TR',
#                                             'TT',
#                                             'TV',
#                                             'TW',
#                                             'TZ',
#                                             'UA',
#                                             'UG',
#                                             'US',
#                                             'UY',
#                                             'UZ',
#                                             'VC',
#                                             'VE',
#                                             'VN',
#                                             'VU',
#                                             'WS',
#                                             'XK',
#                                             'ZA',
#                                             'ZM',
#                                             'ZW'],
#                       'disc_number': 1,
#                       'duration_ms': 302027,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'EGA071800045'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/2QK9spxKFUWe7zeirPHf5O'},
#                       'href': 'https://api.spotify.com/v1/tracks/2QK9spxKFUWe7zeirPHf5O',
#                       'id': '2QK9spxKFUWe7zeirPHf5O',
#                       'is_local': False,
#                       'name': 'حبه جنة',
#                       'popularity': 52,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/e20aabb1c5631b313bc481d3623d0878f80043f2?cid=774b29d4f13844c495f206cafdad9c86',
#                       'track_number': 5,
#                       'type': 'track',
#                       'uri': 'spotify:track:2QK9spxKFUWe7zeirPHf5O'}},
#            {'context': None,
#             'played_at': '2022-10-22T15:43:07.106Z',
#             'track': {'album': {'album_type': 'single',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7FtCyCJCJaxabYO7Uyda5B'},
# ...
#                                                       'NP',
#                                                       'NR',
#                                                       'NZ',
#                                                       'OM',
#                                                       'PA',
#                                                       'PE',
#                                                       'PG',
#                                                       'PH',
#                                                       'PK',
#                                                       'PL',
#                                                       'PS',
#                                                       'PT',
#                                                       'PW',
#                                                       'PY',
#                                                       'QA',
#                                                       'RO',
#                                                       'RS',
#                                                       'RW',
#                                                       'SA',
#                                                       'SB',
#                                                       'SC',
#                                                       'SE',
#                                                       'SG',
#                                                       'SI',
#                                                       'SK',
#                                                       'SL',
#                                                       'SM',
#                                                       'SN',
#                                                       'SR',
#                                                       'ST',
#                                                       'SV',
#                                                       'SZ',
#                                                       'TD',
#                                                       'TG',
#                                                       'TH',
#                                                       'TJ',
#                                                       'TL',
#                                                       'TN',
#                                                       'TO',
#                                                       'TR',
#                                                       'TT',
#                                                       'TV',
#                                                       'TW',
#                                                       'TZ',
#                                                       'UA',
#                                                       'UG',
#                                                       'US',
#                                                       'UY',
#                                                       'UZ',
#                                                       'VC',
#                                                       'VE',
#                                                       'VN',
#                                                       'VU',
#                                                       'WS',
#                                                       'XK',
#                                                       'ZA',
#                                                       'ZM',
#                                                       'ZW'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/4DcKG1Q3jKVu5eUwDQVSQA'},
#                                 'href': 'https://api.spotify.com/v1/albums/4DcKG1Q3jKVu5eUwDQVSQA',
#                                 'id': '4DcKG1Q3jKVu5eUwDQVSQA',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b27360364624e28efa59e9390321',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e0260364624e28efa59e9390321',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000485160364624e28efa59e9390321',
#                                             'width': 64}],
#                                 'name': 'Fire for You',
#                                 'release_date': '2021-01-08',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 2,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:4DcKG1Q3jKVu5eUwDQVSQA'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7FtCyCJCJaxabYO7Uyda5B'},
#                                    'href': 'https://api.spotify.com/v1/artists/7FtCyCJCJaxabYO7Uyda5B',
#                                    'id': '7FtCyCJCJaxabYO7Uyda5B',
#                                    'name': 'Cannons',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:7FtCyCJCJaxabYO7Uyda5B'},
#                                   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4IbUky1dWqlyVlMMTJXPI5'},
#                                    'href': 'https://api.spotify.com/v1/artists/4IbUky1dWqlyVlMMTJXPI5',
#                                    'id': '4IbUky1dWqlyVlMMTJXPI5',
#                                    'name': 'King Henry',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:4IbUky1dWqlyVlMMTJXPI5'}],
#                       'available_markets': ['AD',
#                                             'AE',
#                                             'AG',
#                                             'AL',
#                                             'AM',
#                                             'AO',
#                                             'AR',
#                                             'AT',
#                                             'AU',
#                                             'AZ',
#                                             'BA',
#                                             'BB',
#                                             'BD',
#                                             'BE',
#                                             'BF',
#                                             'BG',
#                                             'BH',
#                                             'BI',
#                                             'BJ',
#                                             'BN',
#                                             'BO',
#                                             'BR',
#                                             'BS',
#                                             'BT',
#                                             'BW',
#                                             'BY',
#                                             'BZ',
#                                             'CA',
#                                             'CD',
#                                             'CG',
#                                             'CH',
#                                             'CI',
#                                             'CL',
#                                             'CM',
#                                             'CO',
#                                             'CR',
#                                             'CV',
#                                             'CW',
#                                             'CY',
#                                             'CZ',
#                                             'DE',
#                                             'DJ',
#                                             'DK',
#                                             'DM',
#                                             'DO',
#                                             'DZ',
#                                             'EC',
#                                             'EE',
#                                             'EG',
#                                             'ES',
#                                             'FI',
#                                             'FJ',
#                                             'FM',
#                                             'FR',
#                                             'GA',
#                                             'GB',
#                                             'GD',
#                                             'GE',
#                                             'GH',
#                                             'GM',
#                                             'GN',
#                                             'GQ',
#                                             'GR',
#                                             'GT',
#                                             'GW',
#                                             'GY',
#                                             'HK',
#                                             'HN',
#                                             'HR',
#                                             'HT',
#                                             'HU',
#                                             'ID',
#                                             'IE',
#                                             'IL',
#                                             'IN',
#                                             'IQ',
#                                             'IS',
#                                             'IT',
#                                             'JM',
#                                             'JO',
#                                             'JP',
#                                             'KE',
#                                             'KG',
#                                             'KH',
#                                             'KI',
#                                             'KM',
#                                             'KN',
#                                             'KR',
#                                             'KW',
#                                             'KZ',
#                                             'LA',
#                                             'LB',
#                                             'LC',
#                                             'LI',
#                                             'LK',
#                                             'LR',
#                                             'LS',
#                                             'LT',
#                                             'LU',
#                                             'LV',
#                                             'LY',
#                                             'MA',
#                                             'MC',
#                                             'MD',
#                                             'ME',
#                                             'MG',
#                                             'MH',
#                                             'MK',
#                                             'ML',
#                                             'MN',
#                                             'MO',
#                                             'MR',
#                                             'MT',
#                                             'MU',
#                                             'MV',
#                                             'MW',
#                                             'MX',
#                                             'MY',
#                                             'MZ',
#                                             'NA',
#                                             'NE',
#                                             'NG',
#                                             'NI',
#                                             'NL',
#                                             'NO',
#                                             'NP',
#                                             'NR',
#                                             'NZ',
#                                             'OM',
#                                             'PA',
#                                             'PE',
#                                             'PG',
#                                             'PH',
#                                             'PK',
#                                             'PL',
#                                             'PS',
#                                             'PT',
#                                             'PW',
#                                             'PY',
#                                             'QA',
#                                             'RO',
#                                             'RS',
#                                             'RW',
#                                             'SA',
#                                             'SB',
#                                             'SC',
#                                             'SE',
#                                             'SG',
#                                             'SI',
#                                             'SK',
#                                             'SL',
#                                             'SM',
#                                             'SN',
#                                             'SR',
#                                             'ST',
#                                             'SV',
#                                             'SZ',
#                                             'TD',
#                                             'TG',
#                                             'TH',
#                                             'TJ',
#                                             'TL',
#                                             'TN',
#                                             'TO',
#                                             'TR',
#                                             'TT',
#                                             'TV',
#                                             'TW',
#                                             'TZ',
#                                             'UA',
#                                             'UG',
#                                             'US',
#                                             'UY',
#                                             'UZ',
#                                             'VC',
#                                             'VE',
#                                             'VN',
#                                             'VU',
#                                             'WS',
#                                             'XK',
#                                             'ZA',
#                                             'ZM',
#                                             'ZW'],
#                       'disc_number': 1,
#                       'duration_ms': 191052,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USSM12006969'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/75Tud73Mry5yYW1xIB7JWg'},
#                       'href': 'https://api.spotify.com/v1/tracks/75Tud73Mry5yYW1xIB7JWg',
#                       'id': '75Tud73Mry5yYW1xIB7JWg',
#                       'is_local': False,
#                       'name': 'Fire for You - King Henry Remix',
#                       'popularity': 36,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/0d31b36a218ea92bc5b8a39f525ea6aee726c3b7?cid=774b29d4f13844c495f206cafdad9c86',
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:75Tud73Mry5yYW1xIB7JWg'}}],
#  'limit': 20,
#  'next': 'https://api.spotify.com/v1/me/player/recently-played?after=1666454188176'}

# %%
#extract what we are looking for (song name, artist name, played at) | we loop through the response to extract the items

song_name = []
artist_name = []
played_at_list = []
timestamps = []

for song in response["items"]:
    song_name.append(song["track"]["name"])
    artist_name.append(song["track"]["album"]["artists"][0]["name"])
    played_at_list.append(song["played_at"])
    timestamps.append(song["played_at"][0:10])

#now let us create a dataframe where we can see the lists we create in a table 

song_dic = {
            "song_name" : song_name,
            "artist_name" : artist_name,
            "played_at" : played_at_list,
            "timestamp" : timestamps,
            }
song_df = pd.DataFrame(song_dic)
song_df.to_csv("my_played_tracks_data.csv")
song_df
# Out:
#                           song_name   artist_name                 played_at  \
# 0                             Yours           ZHU  2022-10-22T15:56:28.176Z
# 1                           حبه جنة       Sherine  2022-10-22T15:50:45.056Z
# 2   Fire for You - King Henry Remix       Cannons  2022-10-22T15:43:07.106Z
# 3                           Chun-Li   Nicki Minaj  2022-10-22T15:39:54.045Z
# 4                           Chun-Li   Nicki Minaj  2022-10-22T15:36:42.700Z
# 5                      Desert Night  RÜFÜS DU SOL  2022-10-21T23:55:55.221Z
# 6                  Treat You Better  RÜFÜS DU SOL  2022-10-21T23:54:40.096Z
# 7     Tie Me Down (with Elley Duhé)       Gryffin  2022-10-21T23:45:30.028Z
# 8   Fire for You - King Henry Remix       Cannons  2022-10-21T23:40:13.733Z
# 9               Simplicity Is Bliss  RÜFÜS DU SOL  2022-10-21T22:59:55.049Z
# 10  Fire for You - King Henry Remix       Cannons  2022-10-21T22:46:49.997Z
# 11  Fire for You - King Henry Remix       Cannons  2022-10-21T22:43:39.225Z
#
#      timestamp
# 0   2022-10-22
# 1   2022-10-22
# 2   2022-10-22
# 3   2022-10-22
# 4   2022-10-22
# 5   2022-10-21
# 6   2022-10-21
# 7   2022-10-21
# 8   2022-10-21
# 9   2022-10-21
# 10  2022-10-21
# 11  2022-10-21

# %%
#Validate
if check_if_validate_data(song_df):
    print("Data is valid, proceed to Load stage")

# Load
engine = sqlalchemy.create_engine("postgresql://postgres:password@localhost:5432/my_played_tracks")

sql_query = """
CREATE TABLE IF NOT EXISTS my_played_tracks(
    song_name VARCHAR(200),
    artist_name VARCHAR(200),
    played_at VARCHAR(200),
    timestamp VARCHAR(200),
    CONSTRINT primary_key_constraint PRIMARY KEY (played_at)
)

"""

try:
    song_df.to_sql("my_played_tracks",engine, index=False, if_exists="append")
except:
    print("Data already exist in the database")

print("Closen database successfully")
# Out:
# Closen database successfully
