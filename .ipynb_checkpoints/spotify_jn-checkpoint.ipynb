# %%
#Dependencies
import requests
import json
import pandas as pd
import numpy as np
import sqlalchemy
from sqlalchemy.orm import sessionmaker
from datetime import datetime
import datetime
import sqlite3
import matplotlib.pyplot as plt
from pprint import pprint

# %%
#my Spotify info
# Make an api request to extract the data from Spotify
user_id = "Alhamzah.alabboodi"
url = "https://api.spotify.com/v1/me/player/recently-played?after="
TOKEN = "BQDoHglWDuIm-Lb_xrFLCieiLimEM3qQrwyvnumMRPwPxDCCT2CkAU2JVcmzI6-SPlkY7OTsgWmSnZT--XsT3pNYdU8Ynh3UmSPcVU7vakwEzXp5HUzb8iBfQqHDP5sm7NuoXZljs8CArAsSqaa7fFrU799lQsxlTqkdq4M7wActU9srh1M5G3Qaq0ennFM"
# response = requests.get(f"{url}{token}")
# response_json = response.json()
# pprint(response_json)

if __name__ == "__main__":
    
    headers = {
        "Accept" : "application/json",
        "content-Type" : "application/json",
        "Authorization" : "Bearer {token}".format(token=TOKEN)
    }
    #sicne today's unix timestamp in milliseconds, we need to convert yesterday's as well
    today = datetime.datetime.now()
    yesterday = today - datetime.timedelta(days=1)
    yesterday_unix_timestamp = int(yesterday.timestamp()) *1000
    
    #preform the request
    request =  requests.get("https://api.spotify.com/v1/me/player/recently-played?after={time}".format(time = yesterday_unix_timestamp), headers = headers)
    response = request.json()
    pprint(response)
# Out:
# {'cursors': {'after': '1666274385977', 'before': '1666198652122'},
#  'href': 'https://api.spotify.com/v1/me/player/recently-played?after=1666198631000',
#  'items': [{'context': None,
#             'played_at': '2022-10-20T13:59:45.977Z',
#             'track': {'album': {'album_type': 'single',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/586uxXMyD5ObPuzjtrzO1Q'},
#                                              'href': 'https://api.spotify.com/v1/artists/586uxXMyD5ObPuzjtrzO1Q',
#                                              'id': '586uxXMyD5ObPuzjtrzO1Q',
#                                              'name': 'Sofi Tukker',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:586uxXMyD5ObPuzjtrzO1Q'},
#                                             {'external_urls': {'spotify': 'https://open.spotify.com/artist/4RqAxYmN6sJO2Ty0tJ2RMy'},
#                                              'href': 'https://api.spotify.com/v1/artists/4RqAxYmN6sJO2Ty0tJ2RMy',
#                                              'id': '4RqAxYmN6sJO2Ty0tJ2RMy',
#                                              'name': 'Novak',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:4RqAxYmN6sJO2Ty0tJ2RMy'},
#                                             {'external_urls': {'spotify': 'https://open.spotify.com/artist/0dPvgsYtDUI9Wcr0WREIJK'},
#                                              'href': 'https://api.spotify.com/v1/artists/0dPvgsYtDUI9Wcr0WREIJK',
#                                              'id': '0dPvgsYtDUI9Wcr0WREIJK',
#                                              'name': 'YAX.X',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:0dPvgsYtDUI9Wcr0WREIJK'}],
#                                 'available_markets': ['AE',
#                                                       'AG',
#                                                       'AM',
#                                                       'AO',
#                                                       'AR',
#                                                       'AU',
#                                                       'AZ',
#                                                       'BB',
#                                                       'BD',
#                                                       'BF',
#                                                       'BH',
#                                                       'BI',
#                                                       'BJ',
#                                                       'BN',
#                                                       'BO',
#                                                       'BR',
#                                                       'BS',
#                                                       'BT',
#                                                       'BW',
#                                                       'BZ',
#                                                       'CA',
#                                                       'CD',
#                                                       'CG',
#                                                       'CI',
#                                                       'CL',
#                                                       'CM',
#                                                       'CO',
#                                                       'CR',
#                                                       'CV',
#                                                       'CW',
#                                                       'DJ',
#                                                       'DM',
#                                                       'DO',
#                                                       'DZ',
#                                                       'EC',
#                                                       'EG',
#                                                       'FJ',
#                                                       'FM',
#                                                       'GA',
#                                                       'GD',
#                                                       'GE',
#                                                       'GH',
#                                                       'GM',
#                                                       'GN',
#                                                       'GQ',
#                                                       'GT',
#                                                       'GW',
#                                                       'GY',
#                                                       'HK',
#                                                       'HN',
#                                                       'HT',
#                                                       'ID',
#                                                       'IL',
#                                                       'IN',
#                                                       'IQ',
#                                                       'JM',
#                                                       'JO',
#                                                       'JP',
#                                                       'KE',
#                                                       'KG',
#                                                       'KH',
#                                                       'KI',
#                                                       'KM',
#                                                       'KN',
#                                                       'KR',
#                                                       'KW',
#                                                       'KZ',
#                                                       'LA',
#                                                       'LB',
#                                                       'LC',
#                                                       'LK',
#                                                       'LR',
#                                                       'LS',
#                                                       'LY',
#                                                       'MA',
#                                                       'MG',
#                                                       'MH',
#                                                       'ML',
#                                                       'MN',
#                                                       'MO',
#                                                       'MR',
#                                                       'MU',
#                                                       'MV',
#                                                       'MW',
#                                                       'MX',
#                                                       'MY',
#                                                       'MZ',
#                                                       'NA',
#                                                       'NE',
#                                                       'NG',
#                                                       'NI',
#                                                       'NP',
#                                                       'NR',
#                                                       'NZ',
#                                                       'OM',
#                                                       'PA',
#                                                       'PE',
#                                                       'PG',
#                                                       'PH',
#                                                       'PK',
#                                                       'PS',
#                                                       'PW',
#                                                       'PY',
#                                                       'QA',
#                                                       'RW',
#                                                       'SA',
#                                                       'SB',
#                                                       'SC',
#                                                       'SG',
#                                                       'SL',
#                                                       'SN',
#                                                       'SR',
#                                                       'ST',
#                                                       'SV',
#                                                       'SZ',
#                                                       'TD',
#                                                       'TG',
#                                                       'TH',
#                                                       'TJ',
#                                                       'TL',
#                                                       'TN',
#                                                       'TO',
#                                                       'TR',
#                                                       'TT',
#                                                       'TV',
#                                                       'TW',
#                                                       'TZ',
#                                                       'UG',
#                                                       'US',
#                                                       'UY',
#                                                       'UZ',
#                                                       'VC',
#                                                       'VE',
#                                                       'VN',
#                                                       'VU',
#                                                       'WS',
#                                                       'ZA',
#                                                       'ZM',
#                                                       'ZW'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/4xeOgbxFCERSTBCaxuKSqY'},
#                                 'href': 'https://api.spotify.com/v1/albums/4xeOgbxFCERSTBCaxuKSqY',
#                                 'id': '4xeOgbxFCERSTBCaxuKSqY',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273fc042d5e8c72239a7a87d710',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02fc042d5e8c72239a7a87d710',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851fc042d5e8c72239a7a87d710',
#                                             'width': 64}],
#                                 'name': 'Emergency',
#                                 'release_date': '2020-09-18',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 1,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:4xeOgbxFCERSTBCaxuKSqY'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/586uxXMyD5ObPuzjtrzO1Q'},
#                                    'href': 'https://api.spotify.com/v1/artists/586uxXMyD5ObPuzjtrzO1Q',
#                                    'id': '586uxXMyD5ObPuzjtrzO1Q',
#                                    'name': 'Sofi Tukker',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:586uxXMyD5ObPuzjtrzO1Q'},
#                                   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4RqAxYmN6sJO2Ty0tJ2RMy'},
#                                    'href': 'https://api.spotify.com/v1/artists/4RqAxYmN6sJO2Ty0tJ2RMy',
#                                    'id': '4RqAxYmN6sJO2Ty0tJ2RMy',
#                                    'name': 'Novak',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:4RqAxYmN6sJO2Ty0tJ2RMy'},
#                                   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0dPvgsYtDUI9Wcr0WREIJK'},
#                                    'href': 'https://api.spotify.com/v1/artists/0dPvgsYtDUI9Wcr0WREIJK',
#                                    'id': '0dPvgsYtDUI9Wcr0WREIJK',
#                                    'name': 'YAX.X',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:0dPvgsYtDUI9Wcr0WREIJK'}],
#                       'available_markets': ['AE',
#                                             'AG',
#                                             'AM',
#                                             'AO',
#                                             'AR',
#                                             'AU',
#                                             'AZ',
#                                             'BB',
#                                             'BD',
#                                             'BF',
#                                             'BH',
#                                             'BI',
#                                             'BJ',
#                                             'BN',
#                                             'BO',
#                                             'BR',
#                                             'BS',
#                                             'BT',
#                                             'BW',
#                                             'BZ',
#                                             'CA',
#                                             'CD',
#                                             'CG',
#                                             'CI',
#                                             'CL',
#                                             'CM',
#                                             'CO',
#                                             'CR',
#                                             'CV',
#                                             'CW',
#                                             'DJ',
#                                             'DM',
#                                             'DO',
#                                             'DZ',
#                                             'EC',
#                                             'EG',
#                                             'FJ',
#                                             'FM',
#                                             'GA',
#                                             'GD',
#                                             'GE',
#                                             'GH',
#                                             'GM',
#                                             'GN',
#                                             'GQ',
#                                             'GT',
#                                             'GW',
#                                             'GY',
#                                             'HK',
#                                             'HN',
#                                             'HT',
#                                             'ID',
#                                             'IL',
#                                             'IN',
#                                             'IQ',
#                                             'JM',
#                                             'JO',
#                                             'JP',
#                                             'KE',
#                                             'KG',
#                                             'KH',
#                                             'KI',
#                                             'KM',
#                                             'KN',
#                                             'KR',
#                                             'KW',
#                                             'KZ',
#                                             'LA',
#                                             'LB',
#                                             'LC',
#                                             'LK',
#                                             'LR',
#                                             'LS',
#                                             'LY',
#                                             'MA',
#                                             'MG',
#                                             'MH',
#                                             'ML',
#                                             'MN',
#                                             'MO',
#                                             'MR',
#                                             'MU',
#                                             'MV',
#                                             'MW',
#                                             'MX',
#                                             'MY',
#                                             'MZ',
#                                             'NA',
#                                             'NE',
#                                             'NG',
#                                             'NI',
#                                             'NP',
#                                             'NR',
#                                             'NZ',
#                                             'OM',
#                                             'PA',
#                                             'PE',
#                                             'PG',
#                                             'PH',
#                                             'PK',
#                                             'PS',
#                                             'PW',
#                                             'PY',
#                                             'QA',
#                                             'RW',
#                                             'SA',
#                                             'SB',
#                                             'SC',
#                                             'SG',
#                                             'SL',
#                                             'SN',
#                                             'SR',
#                                             'ST',
#                                             'SV',
#                                             'SZ',
#                                             'TD',
#                                             'TG',
#                                             'TH',
#                                             'TJ',
#                                             'TL',
#                                             'TN',
#                                             'TO',
#                                             'TR',
#                                             'TT',
#                                             'TV',
#                                             'TW',
#                                             'TZ',
#                                             'UG',
#                                             'US',
#                                             'UY',
#                                             'UZ',
#                                             'VC',
#                                             'VE',
#                                             'VN',
#                                             'VU',
#                                             'WS',
#                                             'ZA',
#                                             'ZM',
#                                             'ZW'],
#                       'disc_number': 1,
#                       'duration_ms': 192760,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'QM37X2000024'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/0iQd47VJs14l8EA00PlI71'},
#                       'href': 'https://api.spotify.com/v1/tracks/0iQd47VJs14l8EA00PlI71',
#                       'id': '0iQd47VJs14l8EA00PlI71',
#                       'is_local': False,
#                       'name': 'Emergency',
#                       'popularity': 45,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/07ca1a52ca34224812f918637ab3c95d54e28a18?cid=774b29d4f13844c495f206cafdad9c86',
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:0iQd47VJs14l8EA00PlI71'}},
#            {'context': None,
#             'played_at': '2022-10-20T13:56:39.090Z',
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Pb27ujIyYb33zBqVysBkj'},
#                                              'href': 'https://api.spotify.com/v1/artists/5Pb27ujIyYb33zBqVysBkj',
#                                              'id': '5Pb27ujIyYb33zBqVysBkj',
#                                              'name': 'RÜFÜS DU SOL',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:5Pb27ujIyYb33zBqVysBkj'}],
#                                 'available_markets': ['AD',
#                                                       'AE',
#                                                       'AG',
#                                                       'AL',
#                                                       'AM',
#                                                       'AO',
#                                                       'AR',
#                                                       'AT',
#                                                       'AZ',
#                                                       'BA',
#                                                       'BB',
#                                                       'BD',
#                                                       'BE',
#                                                       'BF',
#                                                       'BG',
#                                                       'BH',
#                                                       'BI',
#                                                       'BJ',
#                                                       'BN',
#                                                       'BO',
#                                                       'BR',
#                                                       'BS',
#                                                       'BT',
#                                                       'BW',
#                                                       'BY',
#                                                       'BZ',
#                                                       'CA',
#                                                       'CD',
#                                                       'CG',
#                                                       'CH',
#                                                       'CI',
#                                                       'CL',
#                                                       'CM',
#                                                       'CO',
#                                                       'CR',
#                                                       'CV',
#                                                       'CW',
#                                                       'CY',
#                                                       'CZ',
#                                                       'DE',
#                                                       'DJ',
#                                                       'DK',
#                                                       'DM',
#                                                       'DO',
#                                                       'DZ',
#                                                       'EC',
#                                                       'EE',
#                                                       'EG',
#                                                       'ES',
#                                                       'FI',
#                                                       'FJ',
#                                                       'FM',
#                                                       'FR',
#                                                       'GA',
#                                                       'GB',
#                                                       'GD',
#                                                       'GE',
#                                                       'GH',
#                                                       'GM',
#                                                       'GN',
#                                                       'GQ',
#                                                       'GR',
#                                                       'GT',
#                                                       'GW',
#                                                       'GY',
#                                                       'HK',
#                                                       'HN',
#                                                       'HR',
#                                                       'HT',
#                                                       'HU',
#                                                       'ID',
#                                                       'IE',
#                                                       'IL',
#                                                       'IN',
#                                                       'IQ',
#                                                       'IS',
#                                                       'IT',
#                                                       'JM',
#                                                       'JO',
#                                                       'JP',
#                                                       'KE',
#                                                       'KG',
#                                                       'KH',
#                                                       'KI',
#                                                       'KM',
#                                                       'KN',
#                                                       'KR',
#                                                       'KW',
#                                                       'KZ',
#                                                       'LA',
#                                                       'LB',
#                                                       'LC',
#                                                       'LI',
#                                                       'LK',
#                                                       'LR',
#                                                       'LS',
#                                                       'LT',
#                                                       'LU',
#                                                       'LV',
#                                                       'LY',
#                                                       'MA',
#                                                       'MC',
#                                                       'MD',
#                                                       'ME',
#                                                       'MG',
#                                                       'MH',
#                                                       'MK',
#                                                       'ML',
#                                                       'MN',
#                                                       'MO',
#                                                       'MR',
#                                                       'MT',
#                                                       'MU',
#                                                       'MV',
#                                                       'MW',
#                                                       'MX',
#                                                       'MY',
#                                                       'MZ',
#                                                       'NA',
#                                                       'NE',
#                                                       'NG',
#                                                       'NI',
#                                                       'NL',
#                                                       'NO',
#                                                       'NP',
#                                                       'NR',
#                                                       'OM',
#                                                       'PA',
#                                                       'PE',
#                                                       'PG',
#                                                       'PH',
#                                                       'PK',
#                                                       'PL',
#                                                       'PS',
#                                                       'PT',
#                                                       'PW',
#                                                       'PY',
#                                                       'QA',
#                                                       'RO',
#                                                       'RS',
#                                                       'RW',
#                                                       'SA',
#                                                       'SB',
#                                                       'SC',
#                                                       'SE',
#                                                       'SG',
#                                                       'SI',
#                                                       'SK',
#                                                       'SL',
#                                                       'SM',
#                                                       'SN',
#                                                       'SR',
#                                                       'ST',
#                                                       'SV',
#                                                       'SZ',
#                                                       'TD',
#                                                       'TG',
#                                                       'TH',
#                                                       'TJ',
#                                                       'TL',
#                                                       'TN',
#                                                       'TO',
#                                                       'TR',
#                                                       'TT',
#                                                       'TV',
#                                                       'TW',
#                                                       'TZ',
#                                                       'UA',
#                                                       'UG',
#                                                       'US',
#                                                       'UY',
#                                                       'UZ',
#                                                       'VC',
#                                                       'VE',
#                                                       'VN',
#                                                       'VU',
#                                                       'WS',
#                                                       'XK',
#                                                       'ZA',
#                                                       'ZM',
#                                                       'ZW'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/5Jazpq8mEgSgQs06mdwkQd'},
#                                 'href': 'https://api.spotify.com/v1/albums/5Jazpq8mEgSgQs06mdwkQd',
#                                 'id': '5Jazpq8mEgSgQs06mdwkQd',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2734d44b7f4fc30e8522d411bbe',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e024d44b7f4fc30e8522d411bbe',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048514d44b7f4fc30e8522d411bbe',
#                                             'width': 64}],
#                                 'name': 'SOLACE',
#                                 'release_date': '2018-10-19',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 9,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:5Jazpq8mEgSgQs06mdwkQd'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Pb27ujIyYb33zBqVysBkj'},
#                                    'href': 'https://api.spotify.com/v1/artists/5Pb27ujIyYb33zBqVysBkj',
#                                    'id': '5Pb27ujIyYb33zBqVysBkj',
#                                    'name': 'RÜFÜS DU SOL',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:5Pb27ujIyYb33zBqVysBkj'}],
#                       'available_markets': ['AD',
#                                             'AE',
#                                             'AG',
#                                             'AL',
#                                             'AM',
#                                             'AO',
#                                             'AR',
#                                             'AT',
#                                             'AZ',
#                                             'BA',
#                                             'BB',
#                                             'BD',
#                                             'BE',
#                                             'BF',
#                                             'BG',
#                                             'BH',
#                                             'BI',
#                                             'BJ',
#                                             'BN',
#                                             'BO',
#                                             'BR',
#                                             'BS',
#                                             'BT',
#                                             'BW',
#                                             'BY',
#                                             'BZ',
#                                             'CA',
#                                             'CD',
#                                             'CG',
#                                             'CH',
#                                             'CI',
#                                             'CL',
#                                             'CM',
#                                             'CO',
#                                             'CR',
#                                             'CV',
#                                             'CW',
#                                             'CY',
#                                             'CZ',
#                                             'DE',
#                                             'DJ',
#                                             'DK',
#                                             'DM',
#                                             'DO',
#                                             'DZ',
#                                             'EC',
#                                             'EE',
#                                             'EG',
#                                             'ES',
#                                             'FI',
#                                             'FJ',
#                                             'FM',
#                                             'FR',
#                                             'GA',
#                                             'GB',
#                                             'GD',
#                                             'GE',
#                                             'GH',
#                                             'GM',
#                                             'GN',
#                                             'GQ',
#                                             'GR',
#                                             'GT',
#                                             'GW',
#                                             'GY',
#                                             'HK',
#                                             'HN',
#                                             'HR',
#                                             'HT',
#                                             'HU',
#                                             'ID',
#                                             'IE',
#                                             'IL',
#                                             'IN',
#                                             'IQ',
#                                             'IS',
#                                             'IT',
#                                             'JM',
#                                             'JO',
#                                             'JP',
#                                             'KE',
#                                             'KG',
#                                             'KH',
#                                             'KI',
#                                             'KM',
#                                             'KN',
#                                             'KR',
#                                             'KW',
#                                             'KZ',
#                                             'LA',
#                                             'LB',
#                                             'LC',
#                                             'LI',
#                                             'LK',
#                                             'LR',
#                                             'LS',
#                                             'LT',
#                                             'LU',
#                                             'LV',
#                                             'LY',
#                                             'MA',
#                                             'MC',
#                                             'MD',
#                                             'ME',
#                                             'MG',
#                                             'MH',
#                                             'MK',
#                                             'ML',
#                                             'MN',
#                                             'MO',
#                                             'MR',
#                                             'MT',
#                                             'MU',
#                                             'MV',
#                                             'MW',
#                                             'MX',
#                                             'MY',
#                                             'MZ',
#                                             'NA',
#                                             'NE',
#                                             'NG',
#                                             'NI',
#                                             'NL',
#                                             'NO',
#                                             'NP',
#                                             'NR',
#                                             'OM',
#                                             'PA',
#                                             'PE',
#                                             'PG',
#                                             'PH',
#                                             'PK',
#                                             'PL',
#                                             'PS',
#                                             'PT',
#                                             'PW',
#                                             'PY',
#                                             'QA',
#                                             'RO',
#                                             'RS',
#                                             'RW',
#                                             'SA',
#                                             'SB',
#                                             'SC',
#                                             'SE',
#                                             'SG',
#                                             'SI',
#                                             'SK',
#                                             'SL',
#                                             'SM',
#                                             'SN',
#                                             'SR',
#                                             'ST',
#                                             'SV',
#                                             'SZ',
#                                             'TD',
#                                             'TG',
#                                             'TH',
#                                             'TJ',
#                                             'TL',
#                                             'TN',
#                                             'TO',
#                                             'TR',
#                                             'TT',
#                                             'TV',
#                                             'TW',
#                                             'TZ',
#                                             'UA',
#                                             'UG',
#                                             'US',
#                                             'UY',
#                                             'UZ',
#                                             'VC',
#                                             'VE',
#                                             'VN',
#                                             'VU',
#                                             'WS',
#                                             'XK',
#                                             'ZA',
#                                             'ZM',
#                                             'ZW'],
#                       'disc_number': 1,
#                       'duration_ms': 349293,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USRE11800535'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/5ZvHcR4OSwvEV5IhigbTOT'},
#                       'href': 'https://api.spotify.com/v1/tracks/5ZvHcR4OSwvEV5IhigbTOT',
#                       'id': '5ZvHcR4OSwvEV5IhigbTOT',
#                       'is_local': False,
#                       'name': 'Underwater',
#                       'popularity': 65,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/d77dbd45456669cd88965a6a7071aad9935c41ec?cid=774b29d4f13844c495f206cafdad9c86',
#                       'track_number': 7,
#                       'type': 'track',
#                       'uri': 'spotify:track:5ZvHcR4OSwvEV5IhigbTOT'}},
#            {'context': None,
#             'played_at': '2022-10-20T13:50:54.115Z',
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/28j8lBWDdDSHSSt5oPlsX2'},
#                                              'href': 'https://api.spotify.com/v1/artists/28j8lBWDdDSHSSt5oPlsX2',
#                                              'id': '28j8lBWDdDSHSSt5oPlsX2',
#                                              'name': 'ZHU',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:28j8lBWDdDSHSSt5oPlsX2'}],
#                                 'available_markets': ['AD',
#                                                       'AE',
#                                                       'AG',
#                                                       'AL',
#                                                       'AM',
#                                                       'AO',
#                                                       'AR',
#                                                       'AT',
#                                                       'AU',
#                                                       'AZ',
#                                                       'BA',
#                                                       'BB',
#                                                       'BD',
#                                                       'BE',
#                                                       'BF',
#                                                       'BG',
#                                                       'BH',
#                                                       'BI',
#                                                       'BJ',
#                                                       'BN',
#                                                       'BO',
#                                                       'BR',
#                                                       'BS',
#                                                       'BT',
#                                                       'BW',
#                                                       'BY',
#                                                       'BZ',
#                                                       'CA',
#                                                       'CD',
#                                                       'CG',
#                                                       'CH',
#                                                       'CI',
#                                                       'CL',
#                                                       'CM',
#                                                       'CO',
#                                                       'CR',
#                                                       'CV',
#                                                       'CW',
#                                                       'CY',
#                                                       'CZ',
#                                                       'DE',
#                                                       'DJ',
#                                                       'DK',
#                                                       'DM',
#                                                       'DO',
#                                                       'DZ',
#                                                       'EC',
#                                                       'EE',
#                                                       'EG',
#                                                       'ES',
#                                                       'FI',
#                                                       'FJ',
# ...
#                                                       'MX',
#                                                       'MY',
#                                                       'MZ',
#                                                       'NA',
#                                                       'NE',
#                                                       'NG',
#                                                       'NI',
#                                                       'NL',
#                                                       'NO',
#                                                       'NP',
#                                                       'NR',
#                                                       'NZ',
#                                                       'OM',
#                                                       'PA',
#                                                       'PE',
#                                                       'PG',
#                                                       'PH',
#                                                       'PK',
#                                                       'PL',
#                                                       'PS',
#                                                       'PT',
#                                                       'PW',
#                                                       'PY',
#                                                       'QA',
#                                                       'RO',
#                                                       'RS',
#                                                       'RW',
#                                                       'SA',
#                                                       'SB',
#                                                       'SC',
#                                                       'SE',
#                                                       'SG',
#                                                       'SI',
#                                                       'SK',
#                                                       'SL',
#                                                       'SM',
#                                                       'SN',
#                                                       'SR',
#                                                       'ST',
#                                                       'SV',
#                                                       'SZ',
#                                                       'TD',
#                                                       'TG',
#                                                       'TH',
#                                                       'TJ',
#                                                       'TL',
#                                                       'TN',
#                                                       'TO',
#                                                       'TR',
#                                                       'TT',
#                                                       'TV',
#                                                       'TW',
#                                                       'TZ',
#                                                       'UA',
#                                                       'UG',
#                                                       'US',
#                                                       'UY',
#                                                       'UZ',
#                                                       'VC',
#                                                       'VE',
#                                                       'VN',
#                                                       'VU',
#                                                       'WS',
#                                                       'XK',
#                                                       'ZA',
#                                                       'ZM',
#                                                       'ZW'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/3SB9ntsoNwC4oUP6xM9DIN'},
#                                 'href': 'https://api.spotify.com/v1/albums/3SB9ntsoNwC4oUP6xM9DIN',
#                                 'id': '3SB9ntsoNwC4oUP6xM9DIN',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273f014b5a71d5e7b0a9ee64386',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02f014b5a71d5e7b0a9ee64386',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851f014b5a71d5e7b0a9ee64386',
#                                             'width': 64}],
#                                 'name': 'Surrender',
#                                 'release_date': '2021-10-21',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 11,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:3SB9ntsoNwC4oUP6xM9DIN'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Pb27ujIyYb33zBqVysBkj'},
#                                    'href': 'https://api.spotify.com/v1/artists/5Pb27ujIyYb33zBqVysBkj',
#                                    'id': '5Pb27ujIyYb33zBqVysBkj',
#                                    'name': 'RÜFÜS DU SOL',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:5Pb27ujIyYb33zBqVysBkj'}],
#                       'available_markets': ['AD',
#                                             'AE',
#                                             'AG',
#                                             'AL',
#                                             'AM',
#                                             'AO',
#                                             'AR',
#                                             'AT',
#                                             'AU',
#                                             'AZ',
#                                             'BA',
#                                             'BB',
#                                             'BD',
#                                             'BE',
#                                             'BF',
#                                             'BG',
#                                             'BH',
#                                             'BI',
#                                             'BJ',
#                                             'BN',
#                                             'BO',
#                                             'BR',
#                                             'BS',
#                                             'BT',
#                                             'BW',
#                                             'BY',
#                                             'BZ',
#                                             'CA',
#                                             'CD',
#                                             'CG',
#                                             'CH',
#                                             'CI',
#                                             'CL',
#                                             'CM',
#                                             'CO',
#                                             'CR',
#                                             'CV',
#                                             'CW',
#                                             'CY',
#                                             'CZ',
#                                             'DE',
#                                             'DJ',
#                                             'DK',
#                                             'DM',
#                                             'DO',
#                                             'DZ',
#                                             'EC',
#                                             'EE',
#                                             'EG',
#                                             'ES',
#                                             'FI',
#                                             'FJ',
#                                             'FM',
#                                             'FR',
#                                             'GA',
#                                             'GB',
#                                             'GD',
#                                             'GE',
#                                             'GH',
#                                             'GM',
#                                             'GN',
#                                             'GQ',
#                                             'GR',
#                                             'GT',
#                                             'GW',
#                                             'GY',
#                                             'HK',
#                                             'HN',
#                                             'HR',
#                                             'HT',
#                                             'HU',
#                                             'ID',
#                                             'IE',
#                                             'IL',
#                                             'IN',
#                                             'IQ',
#                                             'IS',
#                                             'IT',
#                                             'JM',
#                                             'JO',
#                                             'JP',
#                                             'KE',
#                                             'KG',
#                                             'KH',
#                                             'KI',
#                                             'KM',
#                                             'KN',
#                                             'KR',
#                                             'KW',
#                                             'KZ',
#                                             'LA',
#                                             'LB',
#                                             'LC',
#                                             'LI',
#                                             'LK',
#                                             'LR',
#                                             'LS',
#                                             'LT',
#                                             'LU',
#                                             'LV',
#                                             'LY',
#                                             'MA',
#                                             'MC',
#                                             'MD',
#                                             'ME',
#                                             'MG',
#                                             'MH',
#                                             'MK',
#                                             'ML',
#                                             'MN',
#                                             'MO',
#                                             'MR',
#                                             'MT',
#                                             'MU',
#                                             'MV',
#                                             'MW',
#                                             'MX',
#                                             'MY',
#                                             'MZ',
#                                             'NA',
#                                             'NE',
#                                             'NG',
#                                             'NI',
#                                             'NL',
#                                             'NO',
#                                             'NP',
#                                             'NR',
#                                             'NZ',
#                                             'OM',
#                                             'PA',
#                                             'PE',
#                                             'PG',
#                                             'PH',
#                                             'PK',
#                                             'PL',
#                                             'PS',
#                                             'PT',
#                                             'PW',
#                                             'PY',
#                                             'QA',
#                                             'RO',
#                                             'RS',
#                                             'RW',
#                                             'SA',
#                                             'SB',
#                                             'SC',
#                                             'SE',
#                                             'SG',
#                                             'SI',
#                                             'SK',
#                                             'SL',
#                                             'SM',
#                                             'SN',
#                                             'SR',
#                                             'ST',
#                                             'SV',
#                                             'SZ',
#                                             'TD',
#                                             'TG',
#                                             'TH',
#                                             'TJ',
#                                             'TL',
#                                             'TN',
#                                             'TO',
#                                             'TR',
#                                             'TT',
#                                             'TV',
#                                             'TW',
#                                             'TZ',
#                                             'UA',
#                                             'UG',
#                                             'US',
#                                             'UY',
#                                             'UZ',
#                                             'VC',
#                                             'VE',
#                                             'VN',
#                                             'VU',
#                                             'WS',
#                                             'XK',
#                                             'ZA',
#                                             'ZM',
#                                             'ZW'],
#                       'disc_number': 1,
#                       'duration_ms': 312120,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USRE12100622'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/7K1TsEgLCoNxr7tvPRJgrL'},
#                       'href': 'https://api.spotify.com/v1/tracks/7K1TsEgLCoNxr7tvPRJgrL',
#                       'id': '7K1TsEgLCoNxr7tvPRJgrL',
#                       'is_local': False,
#                       'name': 'Make It Happen',
#                       'popularity': 60,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/b755e79f3b24f204d3e553d5f787625c1bff85fa?cid=774b29d4f13844c495f206cafdad9c86',
#                       'track_number': 2,
#                       'type': 'track',
#                       'uri': 'spotify:track:7K1TsEgLCoNxr7tvPRJgrL'}}],
#  'limit': 20,
#  'next': 'https://api.spotify.com/v1/me/player/recently-played?after=1666274385977'}

# %%
#extract what we are looking for (song name, artist name, played at) | we loop through the response to extract the items

song_name = []
artist_name = []
played_at_list = []
timestamps = []

for song in response["items"]:
    song_name.append(song["track"]["name"])
    artist_name.append(song["track"]["album"]["artists"][0]["name"])
    played_at_list.append(song["played_at"])
    timestamps.append(song["played_at"][0:10])

#now let us create a dataframe where we can see the lists we create in a table 

song_data_df = pd.DataFrame({
            "Song Name" : song_name,
            "Artist Name" : artist_name,
            "Played at Date" : played_at_list,
            "Timestamp" : timestamps
            })
print(song_data_df)

# song_data = pd.DataFrame(song_dic, columns=[""])
# print(song_data)
# Out:
#                           Song Name      Artist Name  \
# 0                         Emergency      Sofi Tukker
# 1                        Underwater     RÜFÜS DU SOL
# 2                           Lost It              ZHU
# 3                           New Sky     RÜFÜS DU SOL
# 4             You Give Me A Feeling  Vintage Culture
# 5                         Breathing       Ben Böhmer
# 6              Escape (feat. Hayla)              Kx5
# 7                  Treat You Better     RÜFÜS DU SOL
# 8                  Treat You Better     RÜFÜS DU SOL
# 9               Simplicity Is Bliss     RÜFÜS DU SOL
# 10  Fire for You - King Henry Remix          Cannons
# 11                       Wet Tennis      Sofi Tukker
# 12                   Make It Happen     RÜFÜS DU SOL
#
#               Played at Date   Timestamp
# 0   2022-10-20T13:59:45.977Z  2022-10-20
# 1   2022-10-20T13:56:39.090Z  2022-10-20
# 2   2022-10-20T13:50:54.115Z  2022-10-20
# 3   2022-10-20T13:48:01.059Z  2022-10-20
# 4   2022-10-20T13:41:10.062Z  2022-10-20
# 5   2022-10-20T13:38:09.166Z  2022-10-20
# 6   2022-10-20T13:34:31.094Z  2022-10-20
# 7   2022-10-20T13:25:33.147Z  2022-10-20
# 8   2022-10-20T13:18:06.213Z  2022-10-20
# 9   2022-10-20T13:07:27.046Z  2022-10-20
# 10  2022-10-20T13:04:22.136Z  2022-10-20
# 11  2022-10-19T18:14:43.641Z  2022-10-19
# 12  2022-10-19T16:57:32.122Z  2022-10-19
